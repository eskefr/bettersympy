# %%
from better_units import *

# %%
Matrix([2/u.s,3/u.m,4*u.m**3])*Integral(2*u.m*s.x,(s.x,u.m/u.s,4*u.m/u.s))
# Out:
# \frac{1}{\text{s}}
# \frac{\text{m}}{\text{s}}
# \text{m}
# \frac{1}{\text{m}}
# \frac{\text{m}}{\text{s}}
# \text{m}
# \text{m}^{3}
# \frac{\text{m}}{\text{s}}
# \text{m}
# Matrix([
# [  2*Integral(2*meter*x, (x, meter/second, 4*meter/second))/second],
# [   3*Integral(2*meter*x, (x, meter/second, 4*meter/second))/meter],
# [4*meter**3*Integral(2*meter*x, (x, meter/second, 4*meter/second))]])

# %%
expr = 3*u.m/u.s**2 * s.t
range = (s.t, 1, 10/u.s**2)
plot(expr, range, xlabel='Time', ylabel='Velocity', title='Velocity vs Time')
